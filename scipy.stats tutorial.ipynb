# %% [markdown]
# # scipy.stats

# %%
# %matplotlib inline
import numpy as np

# %%
from scipy.stats import norm

# %%
sample = norm.rvs(5,1, size=1000)

# %%
import pylab as pl
out = pl.hist(sample)

# %%
xs = np.arange(2,9,0.01)
fxs = norm.pdf(xs, 5,1)
pl.plot(xs,fxs)
